# %% [markdown]
# # Lecture 8: Text Normalization
#
# ## Table of Contents
#
# 1. [Text Normalization](#Text-Normalization)
# 2. [Tokenization](#Tokenization)
# 3. [Stemming](#Stemming)
# 4. [Lemmatization](#Lemmatization)
# 5. [Stop Words](#Stop-Words)
# 6. [Vectorization](#Vectorization)

# %% [markdown]
# ## Text Normalization
#
# Text normalization is the process of transforming text into a single canonical form that it might not have had before. This can involve changing the case of the text, removing punctuation, expanding contractions, and so on. The goal is to transform text into a more standard form that might be easier for other NLP tasks. More importantly, our goal is to think about strategies to represent text in numerical form, which is the only way that machine learning algorithms can process text.
#
# ### Some general stdlib python libraries for text normalization
#
# * `string` (punctuation)
# * `re` (regular expressions)
# * `lower()`, `upper()`, `capitalize()`, `title()` # string methods
# * `split()`, `join()` # more helpful string methods
# * `replace()` # more helpful string methods

# %% [markdown]
# ## Pip installable libraries for text normalization
#
# * `nltk` (Natural Language Toolkit)
# * `spacy` (Industrial Strength NLP)
# * `textblob` (Simplified Text Processing)
# * `gensim` (Topic Modeling for Humans)
# * `stanza` (Python wrapper for Stanford NLP)

# %% [markdown]
# ## Sample text for understading text normalization strategies

# %%
text = """
Human infants have the remarkable ability to learn any human language. One proposed mechanism for this ability 
is distributional learning, where learners infer the underlying cluster structure from unlabeled input. Computational
models of distributional learning have historically been principled but psychologically-implausible
computational-level models, or ad hoc but psychologically plausible algorithmic-level models. Approximate rational
models like particle filters can potentially bridge this divide, and allow principled, but psychologically plausible
models of distributional learning to be specified and evaluated. As a proof of concept, I evaluate one such particle
filter model, applied to learning English voicing categories from distributions of voice-onset times (VOTs). 
I find that this model learns well, but behaves somewhat differently from the standard, unconstrained Gibbs
sampler implementation of the underlying rational model.
"""

# %% [markdown]
# ## Tokenization: breaking text into smaller units

# %% [markdown]
# ### NLTK
#
# NLTK is a slightly outdated platform for building Python programs to work with human language data. Although somewhat outdated, it provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic analysis. NLTK is a great tool for learning NLP, but it is not the best tool for building production systems.

# %%
import nltk
from nltk.tokenize import word_tokenize

nltk_tokens = word_tokenize(text)

print(nltk_tokens, len(nltk_tokens), sep='\n')

# %% [markdown]
# #### NLTK tokenization docs

# %%
word_tokenize??

# %% [markdown]
# ### SpaCy
#
# SpaCy is a modern Python library for industrial-strength natural language processing. It is designed to be fast and accurate, and it includes built-in capabilities for visualizing and analyzing NLP data. SpaCy is a great choice for building real-world NLP applications.

# %%
# tokenize our sample text using spacy

import spacy

NLP = spacy.load('en_core_web_sm')

spacy_tokens = [token.text for token in NLP(text)]

print(spacy_tokens, len(spacy_tokens), sep='\n')

# %%
spacy.tokens.Token??

# %% [markdown]
# ### TextBlob
#
# TextBlob is a simplified text processing library that sits on top of NLTK. It provides an easy-to-use interface to NLTK along with some text processing capabilities of its own. TextBlob is a great choice for getting started with NLP.

# %%
# tokenize the text using the textblob library
from textblob import TextBlob

blob_tokens = TextBlob(text).words

print(blob_tokens, len(blob_tokens), sep='\n')

# %%
funcs = [x for x in dir(TextBlob) if not x.startswith('_')]
funcs

# %% [markdown]
# ### Gensim
#
# Gensim is a Python library for topic modeling, document indexing, and similarity retrieval with large corpora. It is designed to be fast and memory efficient, and it includes capabilities for hierarchical document clustering. Gensim is a great choice for building production NLP systems.
#
# https://tedboy.github.io/nlps/generated/generated/gensim.utils.tokenize.html

# %%
import gensim

# returns a generator
gensim_tokens = list(gensim.utils.tokenize(text))

# get the token count
# gensim_tokens_len = len(list(gensim_tokens))

print(list(gensim_tokens), len(gensim_tokens), sep='\n')

# %%
gensim.utils.tokenize??

# %% [markdown]
# ### Stanford CoreNLP
#
# Stanford CoreNLP is a suite of production-ready natural language analysis tools. It provides a set of human language technology tools that can be used to analyze text. It provides support for tokenization, sentence segmentation, part-of-speech tagging, named entity extraction, chunking, parsing, and coreference resolution. It is written in Java, but it provides a Python wrapper that can be used to access its capabilities.
#
# https://stanfordnlp.github.io/stanza/installation_usage.html#getting-started

# %%
import stanza

# Instantiate our stanza pipeline
stan_NLP = stanza.Pipeline(lang='en', processors='tokenize')

stan_tokens = [token.text for sent in stan_NLP(text).sentences for token in sent.tokens]

# %%
print(stan_tokens, len(stan_tokens), sep='\n')

# %%
stan_NLP??

# %% [markdown]
# ### Tokenization analysis

# %%
from IPython.display import display, Markdown
# Display the token counts
display(Markdown("| NLTK | spaCy | TextBlob | Gensim | Stanza |\n| --- | --- | --- | --- | --- |\n| {} | {} | {} | {} | {} |"\
    .format(len(nltk_tokens),
            len(spacy_tokens),
            len(blob_tokens),
            len(gensim_tokens),
            len(stan_tokens)))
    )

# %%
# Display the texts
display(Markdown("| NLTK | spaCy | TextBlob | Gensim | Stanza |\n| --- | --- | --- | --- | --- |\n| {} | {} | {} | {} | {} |"\
    .format(nltk_tokens,
            spacy_tokens,
            blob_tokens,
            gensim_tokens,
            stan_tokens))
    )

# %% [markdown]
# ## Stemming: (attempting to) reduce words to their root form
#
# Stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base, or root form. For example, the stem of the word `waiting` is `wait`. A stemming algorithm reduces the words `waiting`, `waits`, and `waited` to the same stem. This is important in building NLP systems because it helps us ensure that we are processing all forms of a word using the same representation.

# %% [markdown]
# ### NLTK
#
# https://www.nltk.org/howto/stem.html

# %%
## NLTK Stemming

## import the PorterStemmer
from nltk.stem import PorterStemmer

## Create an instance of the PorterStemmer
stemmer = PorterStemmer()

## Stem the tokens
nltk_stemmed_tokens = [stemmer.stem(token) for token in nltk_tokens]

# %%
nltk_stemmed = " ".join(nltk_stemmed_tokens)

# Display the stemmed text
print(nltk_stemmed[:100])

# %% [markdown]
# ### SpaCy
#
# https://spacy.io/api/lemmatizer
#
# See below for SpaCy lemmatization

# %% [markdown]
# ### TextBlob
#
# https://textblob.readthedocs.io/en/dev/quickstart.html#stemming

# %%
## TextBlob Stemming

## Stem the tokens
blob = TextBlob(text)

blob_stemmed_tokens = [word.stem() for word in blob.words]

# %% [markdown]
# ### Gensim
#
# https://tedboy.github.io/nlps/generated/generated/gensim.parsing.porter.PorterStemmer.html

# %%
import gensim
from gensim.parsing.porter import PorterStemmer

gensim_stemmed_tokens = [PorterStemmer().stem(token) for token in gensim_tokens]

# %%
gensim_stemmed_tokens = " ".join(gensim_stemmed_tokens)
gensim_stemmed_tokens[:100]

# %% [markdown]
# ### Stanza
#
# Stanza does not have a built-in stemmer, but it does have a lemmatizer. See below for Stanza lemmatization.

# %% [markdown]
# ### Comparison of stemming algorithms

# %%
# Display the stemmed texts
display(Markdown("| NLTK | TextBlob | Gensim |\n| --- | --- | --- |\n| {} | {} | {} |"\
    .format(nltk_stemmed_tokens,
            blob_stemmed_tokens,
            gensim_stemmed_tokens))
        )

# %% [markdown]
# ## Lemmatization: reducing words to their dictionary form
#
# Lemmatization is the linguistic process of reducing the groups of inflected forms of a word so they can be analysed as a single item, identified by the word's lemma, or dictionary form.
#
# | Case | Masc. | Fem. | Neut. |
# |------|-------|------|-------|
# | nominative | der | die | das |
# | accusative | den | die | das |
# | dative | dem | der | dem |
# | genitive | des | der | des |

# %% [markdown]
# ### NLTK
#
# https://www.nltk.org/_modules/nltk/stem/wordnet.html

# %%
import nltk
nltk.download('wordnet')

## NLTK Lemmatization
from nltk.stem import WordNetLemmatizer


# Create an instance of the WordNetLemmatizer
nltk_lemmatizer = WordNetLemmatizer()

# Lemmatize the tokens
nltk_lemmas = [nltk_lemmatizer.lemmatize(token) for token in nltk_tokens]

# %%
print(" ".join(nltk_lemmas))

# %% [markdown]
# ### SpaCy
#
# https://spacy.io/api/lemmatizer

# %%
## SpaCy Lemmatization
import spacy

## Create an instance of the spaCy library
spacy_NLP = spacy.load('en_core_web_sm')

## Lemmatize the tokens
spacy_lemmas = [token.lemma_ for token in spacy_NLP(text)]

# %%
print(" ".join(spacy_lemmas))

# %% [markdown]
# ### TextBlob

# %%
from textblob import TextBlob

## Create an instance of the TextBlob library
blob = TextBlob(text)

## Lemmatize the blob
blob_lemmas = [word.lemmatize() for word in blob.words]

# %%
print(" ".join(blob_lemmas))

# %% [markdown]
# ### Gensim
#
# Gensim no longer has a lemmatizer.

# %% [markdown]
# ### Stanza
#
# https://stanfordnlp.github.io/stanza/lemma.html

# %%
import stanza

## Create an instance of the stanza library
stanza_NLP = stanza.Pipeline(lang='en', processors='tokenize,lemma')

## Create a document object
doc = stanza_NLP(text)

# Stanza lemmas
stanza_lemmas = [word.lemma for sent in doc.sentences for word in sent.words]

## Lemmatize the tokens
print(*[f'word: {word.text+" "}\tlemma: {word.lemma}' for sent in doc.sentences for word in sent.words], sep='\n')

# %%
# Display the lemmatized texts
display(Markdown("| NLTK | spaCy | TextBlob | Stanza |\n| --- | --- | --- | --- |\n| {} | {} | {} | {} |"\
    .format(nltk_lemmas,
            spacy_lemmas,
            blob_lemmas,
            stanza_lemmas))
        )

# %% [markdown]
# ## Stopword lists
#
# `Stopwords` are words that are so common that they are not useful for analysis. For example, the word `the` is a stopword. To nomralize our text with stopwords, we remove them from our corpus.

# %% [markdown]
# ### NLTK
#
# https://www.nltk.org/book/ch02.html#stopwords_index_term

# %%
## NLTK Stopwords

## Import the stopwords
from nltk.corpus import stopwords

print(stopwords.words('english'))

# %% [markdown]
# ### SpaCy
#
# https://spacy.io/api/language#section-defaults

# %%
import spacy

## Create a list of SpaCy stopwords in English
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

spacy_stopwords

# %% [markdown]
# ### TextBlob
#
# TextBlob relies on NLTK for stopword lists.

# %% [markdown]
# ### Gensim
#
# https://radimrehurek.com/gensim/parsing/preprocessing.html

# %%
import gensim
from gensim.parsing.preprocessing import STOPWORDS

STOPWORDS

# %% [markdown]
# ### Create your own stopword list using Zipf's Law or other statistical methods

# %% [markdown]
# ## Interesting features of Spacy and Stanza

# %%
import spacy

## Create an instance of the spaCy library
NLP = spacy.load('en_core_web_sm')

doc = NLP(text)

for token in doc:
    print(f'{token.text=}, {token.is_stop=}, {token.is_punct=}, {token.is_space=}, {token.is_alpha=}, {token.is_digit=}')
# Out:
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='Human', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='infants', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='have', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='the', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='remarkable', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='ability', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='to', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learn', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='any', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='human', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='language', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='One', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='proposed', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='mechanism', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='for', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='this', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='ability', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='is', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='distributional', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learning', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='where', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learners', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='infer', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='the', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='underlying', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='cluster', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='structure', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='from', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='unlabeled', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='input', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='Computational', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='models', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='of', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='distributional', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learning', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='have', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='historically', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='been', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='principled', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='but', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='psychologically', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='-', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='implausible', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='computational', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='-', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='level', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='models', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='or', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='ad', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='hoc', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='but', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='psychologically', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='plausible', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='algorithmic', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='-', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='level', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='models', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='Approximate', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='rational', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='models', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='like', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='particle', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='filters', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='can', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='potentially', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='bridge', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='this', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='divide', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='and', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='allow', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='principled', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='but', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='psychologically', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='plausible', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='models', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='of', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='distributional', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learning', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='to', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='be', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='specified', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='and', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='evaluated', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='As', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='a', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='proof', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='of', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='concept', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='I', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='evaluate', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='one', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='such', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='particle', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='filter', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='model', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='applied', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='to', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learning', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='English', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='voicing', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='categories', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='from', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='distributions', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='of', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='voice', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='-', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='onset', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='times', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='(', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='VOTs', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=')', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='I', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='find', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='that', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='this', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='model', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='learns', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='well', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='but', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='behaves', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='somewhat', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='differently', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='from', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='the', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='standard', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text=',', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='unconstrained', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='Gibbs', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False
# token.text='sampler', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='implementation', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='of', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='the', token.is_stop=True, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='underlying', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='rational', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='model', token.is_stop=False, token.is_punct=False, token.is_space=False, token.is_alpha=True, token.is_digit=False
# token.text='.', token.is_stop=False, token.is_punct=True, token.is_space=False, token.is_alpha=False, token.is_digit=False
# token.text='\n', token.is_stop=False, token.is_punct=False, token.is_space=True, token.is_alpha=False, token.is_digit=False

# %%
# dependency parsing

import spacy

## Create an instance of the spaCy library

NLP = spacy.load('en_core_web_sm')

## Create a document object
doc = NLP(text)

## Print the dependency parsing
for token in doc:
    print(f'{token.text} <--{token.dep_}-- {token.head.text}')
    
# graph the dependency parsing
from spacy import displacy

displacy.render(doc, style='dep', jupyter=True)
# Out:
#  <--dep-- Human
# Human <--amod-- infants
# infants <--nsubj-- have
# have <--ROOT-- have
# the <--det-- ability
# remarkable <--amod-- ability
# ability <--dobj-- have
# to <--aux-- learn
# learn <--acl-- ability
# any <--det-- language
# human <--amod-- language
# language <--dobj-- learn
# . <--punct-- have
# One <--nummod-- mechanism
# proposed <--amod-- mechanism
# mechanism <--nsubj-- is
# for <--prep-- mechanism
# this <--det-- ability
# ability <--pobj-- for
#
#  <--dep-- ability
# is <--ROOT-- is
# distributional <--amod-- learning
# learning <--attr-- is
# , <--punct-- learning
# where <--advmod-- infer
# learners <--nsubj-- infer
# infer <--relcl-- learning
# the <--det-- structure
# underlying <--amod-- structure
# cluster <--compound-- structure
# structure <--dobj-- infer
# from <--prep-- structure
# unlabeled <--amod-- input
# input <--pobj-- from
# . <--punct-- is
# Computational <--amod-- models
#
#  <--dep-- Computational
# models <--nsubjpass-- principled
# of <--prep-- models
# distributional <--amod-- learning
# learning <--pobj-- of
# have <--aux-- principled
# historically <--advmod-- principled
# been <--auxpass-- principled
# principled <--ROOT-- principled
# but <--cc-- principled
# psychologically <--advmod-- implausible
# - <--punct-- implausible
# implausible <--amod-- models
#
#  <--dep-- implausible
# computational <--amod-- level
# - <--punct-- level
# level <--compound-- models
# models <--conj-- principled
# , <--punct-- models
# or <--cc-- models
# ad <--nmod-- hoc
# hoc <--amod-- models
# but <--cc-- hoc
# psychologically <--advmod-- plausible
# plausible <--amod-- models
# algorithmic <--amod-- level
# - <--punct-- level
# level <--compound-- models
# models <--conj-- models
# . <--punct-- principled
# Approximate <--amod-- models
# rational <--amod-- models
#
#  <--dep-- rational
# models <--nsubj-- bridge
# like <--prep-- models
# particle <--compound-- filters
# filters <--nsubj-- bridge
# can <--aux-- bridge
# potentially <--advmod-- bridge
# bridge <--ROOT-- bridge
# this <--det-- divide
# divide <--dobj-- bridge
# , <--punct-- bridge
# and <--cc-- bridge
# allow <--conj-- bridge
# principled <--dobj-- allow
# , <--punct-- principled
# but <--cc-- principled
# psychologically <--advmod-- plausible
# plausible <--amod-- models
#
#  <--dep-- plausible
# models <--nsubjpass-- specified
# of <--prep-- models
# distributional <--amod-- learning
# learning <--pobj-- of
# to <--aux-- specified
# be <--auxpass-- specified
# specified <--ccomp-- allow
# and <--cc-- specified
# evaluated <--conj-- specified
# . <--punct-- bridge
# As <--prep-- evaluate
# a <--det-- proof
# proof <--pobj-- As
# of <--prep-- proof
# concept <--pobj-- of
# , <--punct-- evaluate
# I <--nsubj-- evaluate
# evaluate <--ROOT-- evaluate
# one <--nummod-- model
# such <--amod-- model
# particle <--compound-- model
#
#  <--dep-- particle
# filter <--compound-- model
# model <--dobj-- evaluate
# , <--punct-- model
# applied <--acl-- model
# to <--prep-- applied
# learning <--pcomp-- to
# English <--compound-- categories
# voicing <--compound-- categories
# categories <--dobj-- learning
# from <--prep-- learning
# distributions <--pobj-- from
# of <--prep-- distributions
# voice <--compound-- onset
# - <--punct-- onset
# onset <--compound-- times
# times <--pobj-- of
# ( <--punct-- times
# VOTs <--appos-- times
# ) <--punct-- model
# . <--punct-- evaluate
#
#  <--dep-- .
# I <--nsubj-- find
# find <--ROOT-- find
# that <--mark-- learns
# this <--det-- model
# model <--nsubj-- learns
# learns <--ccomp-- find
# well <--advmod-- learns
# , <--punct-- find
# but <--cc-- find
# behaves <--conj-- find
# somewhat <--advmod-- differently
# differently <--advmod-- behaves
# from <--prep-- behaves
# the <--det-- standard
# standard <--pobj-- from
# , <--punct-- implementation
# unconstrained <--amod-- implementation
# Gibbs <--compound-- sampler
#
#  <--dep-- Gibbs
# sampler <--compound-- implementation
# implementation <--dobj-- behaves
# of <--prep-- implementation
# the <--det-- model
# underlying <--amod-- model
# rational <--amod-- model
# model <--pobj-- of
# . <--punct-- find
#
#  <--dep-- .
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="79fd47fe2b6d44599dc35220d53c8b84-0" class="displacy" width="24200" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">infants</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">remarkable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">learn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">language.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">proposed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">mechanism</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">ability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">distributional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">learning,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">learners</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">infer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">underlying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">cluster</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">structure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">unlabeled</tspan>
#     <tspan class="displacy-

# %%
# Named Entity Recognition
import spacy

## Create an instance of the spaCy library
NLP = spacy.load('en_core_web_sm')

## Create a document object
doc = NLP(text)

## Print the named entities
for ent in doc.ents:
    print(f'{ent.text} - {ent.label_}')
# Out:
# One - CARDINAL
# one - CARDINAL
# English - LANGUAGE
# Gibbs - GPE

# %%
# create semantic triples
import spacy

## Create an instance of the spaCy library
NLP = spacy.load('en_core_web_sm')

## Create a document object
doc = NLP(text)

## Create a list of triples
triples = [(token.text, token.dep_, token.head.text) for token in doc]

## Print the triples
for triple in triples:
    print(triple)
# Out:
# ('\n', 'dep', 'Human')
# ('Human', 'amod', 'infants')
# ('infants', 'nsubj', 'have')
# ('have', 'ROOT', 'have')
# ('the', 'det', 'ability')
# ('remarkable', 'amod', 'ability')
# ('ability', 'dobj', 'have')
# ('to', 'aux', 'learn')
# ('learn', 'acl', 'ability')
# ('any', 'det', 'language')
# ('human', 'amod', 'language')
# ('language', 'dobj', 'learn')
# ('.', 'punct', 'have')
# ('One', 'nummod', 'mechanism')
# ('proposed', 'amod', 'mechanism')
# ('mechanism', 'nsubj', 'is')
# ('for', 'prep', 'mechanism')
# ('this', 'det', 'ability')
# ('ability', 'pobj', 'for')
# ('\n', 'dep', 'ability')
# ('is', 'ROOT', 'is')
# ('distributional', 'amod', 'learning')
# ('learning', 'attr', 'is')
# (',', 'punct', 'learning')
# ('where', 'advmod', 'infer')
# ('learners', 'nsubj', 'infer')
# ('infer', 'relcl', 'learning')
# ('the', 'det', 'structure')
# ('underlying', 'amod', 'structure')
# ('cluster', 'compound', 'structure')
# ('structure', 'dobj', 'infer')
# ('from', 'prep', 'structure')
# ('unlabeled', 'amod', 'input')
# ('input', 'pobj', 'from')
# ('.', 'punct', 'is')
# ('Computational', 'amod', 'models')
# ('\n', 'dep', 'Computational')
# ('models', 'nsubjpass', 'principled')
# ('of', 'prep', 'models')
# ('distributional', 'amod', 'learning')
# ('learning', 'pobj', 'of')
# ('have', 'aux', 'principled')
# ('historically', 'advmod', 'principled')
# ('been', 'auxpass', 'principled')
# ('principled', 'ROOT', 'principled')
# ('but', 'cc', 'principled')
# ('psychologically', 'advmod', 'implausible')
# ('-', 'punct', 'implausible')
# ('implausible', 'amod', 'models')
# ('\n', 'dep', 'implausible')
# ('computational', 'amod', 'level')
# ('-', 'punct', 'level')
# ('level', 'compound', 'models')
# ('models', 'conj', 'principled')
# (',', 'punct', 'models')
# ('or', 'cc', 'models')
# ('ad', 'nmod', 'hoc')
# ('hoc', 'amod', 'models')
# ('but', 'cc', 'hoc')
# ('psychologically', 'advmod', 'plausible')
# ('plausible', 'amod', 'models')
# ('algorithmic', 'amod', 'level')
# ('-', 'punct', 'level')
# ('level', 'compound', 'models')
# ('models', 'conj', 'models')
# ('.', 'punct', 'principled')
# ('Approximate', 'amod', 'models')
# ('rational', 'amod', 'models')
# ('\n', 'dep', 'rational')
# ('models', 'nsubj', 'bridge')
# ('like', 'prep', 'models')
# ('particle', 'compound', 'filters')
# ('filters', 'nsubj', 'bridge')
# ('can', 'aux', 'bridge')
# ('potentially', 'advmod', 'bridge')
# ('bridge', 'ROOT', 'bridge')
# ('this', 'det', 'divide')
# ('divide', 'dobj', 'bridge')
# (',', 'punct', 'bridge')
# ('and', 'cc', 'bridge')
# ('allow', 'conj', 'bridge')
# ('principled', 'dobj', 'allow')
# (',', 'punct', 'principled')
# ('but', 'cc', 'principled')
# ('psychologically', 'advmod', 'plausible')
# ('plausible', 'amod', 'models')
# ('\n', 'dep', 'plausible')
# ('models', 'nsubjpass', 'specified')
# ('of', 'prep', 'models')
# ('distributional', 'amod', 'learning')
# ('learning', 'pobj', 'of')
# ('to', 'aux', 'specified')
# ('be', 'auxpass', 'specified')
# ('specified', 'ccomp', 'allow')
# ('and', 'cc', 'specified')
# ('evaluated', 'conj', 'specified')
# ('.', 'punct', 'bridge')
# ('As', 'prep', 'evaluate')
# ('a', 'det', 'proof')
# ('proof', 'pobj', 'As')
# ('of', 'prep', 'proof')
# ('concept', 'pobj', 'of')
# (',', 'punct', 'evaluate')
# ('I', 'nsubj', 'evaluate')
# ('evaluate', 'ROOT', 'evaluate')
# ('one', 'nummod', 'model')
# ('such', 'amod', 'model')
# ('particle', 'compound', 'model')
# ('\n', 'dep', 'particle')
# ('filter', 'compound', 'model')
# ('model', 'dobj', 'evaluate')
# (',', 'punct', 'model')
# ('applied', 'acl', 'model')
# ('to', 'prep', 'applied')
# ('learning', 'pcomp', 'to')
# ('English', 'compound', 'categories')
# ('voicing', 'compound', 'categories')
# ('categories', 'dobj', 'learning')
# ('from', 'prep', 'learning')
# ('distributions', 'pobj', 'from')
# ('of', 'prep', 'distributions')
# ('voice', 'compound', 'onset')
# ('-', 'punct', 'onset')
# ('onset', 'compound', 'times')
# ('times', 'pobj', 'of')
# ('(', 'punct', 'times')
# ('VOTs', 'appos', 'times')
# (')', 'punct', 'model')
# ('.', 'punct', 'evaluate')
# ('\n', 'dep', '.')
# ('I', 'nsubj', 'find')
# ('find', 'ROOT', 'find')
# ('that', 'mark', 'learns')
# ('this', 'det', 'model')
# ('model', 'nsubj', 'learns')
# ('learns', 'ccomp', 'find')
# ('well', 'advmod', 'learns')
# (',', 'punct', 'find')
# ('but', 'cc', 'find')
# ('behaves', 'conj', 'find')
# ('somewhat', 'advmod', 'differently')
# ('differently', 'advmod', 'behaves')
# ('from', 'prep', 'behaves')
# ('the', 'det', 'standard')
# ('standard', 'pobj', 'from')
# (',', 'punct', 'implementation')
# ('unconstrained', 'amod', 'implementation')
# ('Gibbs', 'compound', 'sampler')
# ('\n', 'dep', 'Gibbs')
# ('sampler', 'compound', 'implementation')
# ('implementation', 'dobj', 'behaves')
# ('of', 'prep', 'implementation')
# ('the', 'det', 'model')
# ('underlying', 'amod', 'model')
# ('rational', 'amod', 'model')
# ('model', 'pobj', 'of')
# ('.', 'punct', 'find')
# ('\n', 'dep', '.')
